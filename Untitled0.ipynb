# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexTokarev85/-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_drinks(num_guests, duration, alcohol_percent):
    # Средние нормы потребления
    alcohol_per_hour = 0.175  # литров на человека в час
    non_alcohol_per_hour = 0.35  # литров на человека в час

    # Расчет объемов
    alcohol_volume = num_guests * (alcohol_percent / 100) * duration * alcohol_per_hour
    non_alcohol_volume = num_guests * (1 - alcohol_percent / 100) * duration * non_alcohol_per_hour

    return alcohol_volume, non_alcohol_volume

# Пример вызова функции
num_guests = 50
duration = 4  # в часах
alcohol_percent = 60  # процент тех, кто будет пить алкоголь

alcohol, non_alcohol = calculate_drinks(num_guests, duration, alcohol_percent)
print(f"Необходимый объем алкоголя: {alcohol:.2f} литров")
print(f"Необходимый объем безалкогольных напитков: {non_alcohol:.2f} литров")
# Out:
# Необходимый объем алкоголя: 21.00 литров
# Необходимый объем безалкогольных напитков: 28.00 литров

# %%
import matplotlib.pyplot as plt

# Функция расчета количества напитков
def calculate_drinks(num_guests, duration, drink_params):
    results = {}
    for drink, params in drink_params.items():
        volume_per_person_per_hour = params['volume_per_person_per_hour']
        percentage = params['percentage']
        total_volume = num_guests * (percentage / 100) * duration * volume_per_person_per_hour
        results[drink] = total_volume
    return results

# Параметры напитков (в литрах на человека в час)
drink_params = {
    'Вино': {
        'volume_per_person_per_hour': 0.15,  # 150 мл
        'percentage': 50  # 50% гостей будут пить вино
    },
    'Пиво': {
        'volume_per_person_per_hour': 0.2,  # 200 мл
        'percentage': 30  # 30% гостей будут пить пиво
    },
    'Водка': {
        'volume_per_person_per_hour': 0.05,  # 50 мл
        'percentage': 20  # 20% гостей будут пить водку
    },
    'Сок': {
        'volume_per_person_per_hour': 0.25,  # 250 мл
        'percentage': 60  # 60% гостей будут пить сок
    },
    'Вода': {
        'volume_per_person_per_hour': 0.2,  # 200 мл
        'percentage': 70  # 70% гостей будут пить воду
    }
}

# Вводные данные
num_guests = 100  # Количество гостей
duration = 4  # Продолжительность фуршета в часах

# Расчет объемов напитков
drink_volumes = calculate_drinks(num_guests, duration, drink_params)

# Визуализация результатов
labels = list(drink_volumes.keys())
volumes = list(drink_volumes.values())

plt.figure(figsize=(10, 7))
plt.bar(labels, volumes, color=['#FF9999', '#66B2FF', '#FFCC99', '#99FF99', '#FF6666'])
plt.xlabel('Тип напитка')
plt.ylabel('Объем (литры)')
plt.title(f'Объем напитков на фуршете для {num_guests} гостей на {duration} часа')
plt.show()

# %%
import matplotlib.pyplot as plt

# Функция расчета количества напитков
def calculate_drinks(num_guests, duration, drink_params):
    results = {}
    for drink, params in drink_params.items():
        volume_per_person_per_hour = params['volume_per_person_per_hour']
        percentage = params['percentage']
        total_volume = num_guests * (percentage / 100) * duration * volume_per_person_per_hour
        results[drink] = total_volume
    return results

# Параметры напитков (в литрах на человека в час)
drink_params = {
    'Вино белое': {
        'volume_per_person_per_hour': 0.15,  # 150 мл
        'percentage': 20  # 20% гостей будут пить белое вино
    },
    'Вино красное': {
        'volume_per_person_per_hour': 0.15,  # 150 мл
        'percentage': 20  # 20% гостей будут пить красное вино
    },
    'Шампанское': {
        'volume_per_person_per_hour': 0.1,  # 100 мл
        'percentage': 15  # 15% гостей будут пить шампанское
    },
    'Виски': {
        'volume_per_person_per_hour': 0.05,  # 50 мл
        'percentage': 10  # 10% гостей будут пить виски
    },
    'Коньяк': {
        'volume_per_person_per_hour': 0.05,  # 50 мл
        'percentage': 5  # 5% гостей будут пить коньяк
    },
    'Водка': {
        'volume_per_person_per_hour': 0.05,  # 50 мл
        'percentage': 10  # 10% гостей будут пить водку
    },
    'Вода с газом': {
        'volume_per_person_per_hour': 0.25,  # 250 мл
        'percentage': 30  # 30% гостей будут пить газированную воду
    },
    'Вода без газа': {
        'volume_per_person_per_hour': 0.25,  # 250 мл
        'percentage': 40  # 40% гостей будут пить негазированную воду
    },
    'Сок апельсиновый': {
        'volume_per_person_per_hour': 0.25,  # 250 мл
        'percentage': 20  # 20% гостей будут пить апельсиновый сок
    },
    'Сок мультифрукт': {
        'volume_per_person_per_hour': 0.25,  # 250 мл
        'percentage': 20  # 20% гостей будут пить мультифруктовый сок
    },
    'Сок яблочный': {
        'volume_per_person_per_hour': 0.25,  # 250 мл
        'percentage': 20  # 20% гостей будут пить яблочный сок
    }
}

# Вводные данные
num_guests = 100  # Количество гостей
duration = 4  # Продолжительность фуршета в часах

# Расчет объемов напитков
drink_volumes = calculate_drinks(num_guests, duration, drink_params)

# Визуализация результатов
labels = list(drink_volumes.keys())
volumes = list(drink_volumes.values())

plt.figure(figsize=(12, 8))
plt.bar(labels, volumes, color=['#FF9999', '#FF6666', '#FFCC99', '#CC9999', '#CC6666', '#FFB266',
                                '#66B2FF', '#66CCFF', '#99FF99', '#99CC66', '#99CC99'])
plt.xlabel('Тип напитка')
plt.ylabel('Объем (литры)')
plt.title(f'Объем напитков на фуршете для {num_guests} гостей на {duration} часа')
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
import plotly.graph_objs as go
import plotly.express as px
import ipywidgets as widgets
from ipywidgets import interactive
from IPython.display import display

# Функция для расчета объема напитков
def calculate_drinks(num_guests, duration, drink_params):
    results = {}
    for drink, params in drink_params.items():
        volume_per_person_per_hour = params['volume_per_person_per_hour']
        percentage = params['percentage']
        total_volume = num_guests * (percentage / 100) * duration * volume_per_person_per_hour
        results[drink] = total_volume
    return results

# Параметры напитков (в литрах на человека в час)
default_drink_params = {
    'Вино белое': {'volume_per_person_per_hour': 0.15, 'percentage': 20},
    'Вино красное': {'volume_per_person_per_hour': 0.15, 'percentage': 20},
    'Шампанское': {'volume_per_person_per_hour': 0.1, 'percentage': 15},
    'Виски': {'volume_per_person_per_hour': 0.05, 'percentage': 10},
    'Коньяк': {'volume_per_person_per_hour': 0.05, 'percentage': 5},
    'Водка': {'volume_per_person_per_hour': 0.05, 'percentage': 10},
    'Вода с газом': {'volume_per_person_per_hour': 0.25, 'percentage': 30},
    'Вода без газа': {'volume_per_person_per_hour': 0.25, 'percentage': 40},
    'Сок апельсиновый': {'volume_per_person_per_hour': 0.25, 'percentage': 20},
    'Сок мультифрукт': {'volume_per_person_per_hour': 0.25, 'percentage': 20},
    'Сок яблочный': {'volume_per_person_per_hour': 0.25, 'percentage': 20}
}

# Функция для создания и отображения интерактивной диаграммы
def update_plot(num_guests, duration, **drink_params):
    # Обновление параметров напитков
    drink_params_updated = {k: {'volume_per_person_per_hour': v[0], 'percentage': v[1]}
                            for k, v in drink_params.items()}

    # Расчет объемов напитков
    drink_volumes = calculate_drinks(num_guests, duration, drink_params_updated)

    # Создание бар-чарта с Plotly
    fig = go.Figure(data=[
        go.Bar(x=list(drink_volumes.keys()), y=list(drink_volumes.values()),
               text=[f'{v:.2f} л' for v in drink_volumes.values()],
               textposition='auto')
    ])

    fig.update_layout(
        title=f'Объем напитков на фуршете для {num_guests} гостей на {duration} часа',
        xaxis_title='Тип напитка',
        yaxis_title='Объем (литры)',
        xaxis_tickangle=-45
    )

    fig.show()

# Создание интерактивных виджетов для каждого параметра
widgets_params = {drink: widgets.FloatRangeSlider(
                    value=[params['volume_per_person_per_hour'], params['percentage']],
                    min=0.0, max=100.0, step=0.05,
                    description=drink, continuous_update=False,
                    layout=widgets.Layout(width='70%')
                 ) for drink, params in default_drink_params.items()}

# Интерактивные виджеты для количества гостей и длительности
num_guests_widget = widgets.IntSlider(value=100, min=1, max=500, step=1, description='Гостей:')
duration_widget = widgets.IntSlider(value=4, min=1, max=12, step=1, description='Часы:')

# Создание интерактивного интерфейса
interactive_plot = interactive(update_plot, num_guests=num_guests_widget,
                               duration=duration_widget, **widgets_params)

# Отображение интерфейса
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=100, description='Гостей:', max=500, min=1), IntSlider(value=4, descript…
